# %% [markdown]
# # $s_{11}$ Phase Investigations

# %%
import S2P_Tools as s2p

# %%
frequency, s11_mag, s11_phase, s21_mag, s21_phase = s2p.parameters(r"Simulated Data\garnetonly_widerange_real_imag.S2P", True)
frequency, s11_mag, s11_phase, s21_mag, s21_phase = s2p.parameters(r"Simulated Data\garnetonly_lowrage_real_imag.S2P", True)
frequency, s11_mag, s11_phase, s21_mag, s21_phase = s2p.parameters(r"Simulated Data\garnetonly_superlowrage_real_imag.S2P", True)
frequency, s11_mag, s11_phase, s21_mag, s21_phase = s2p.parameters(r"Simulated Data\GarnetOnlySimulated.S2P", True)
frequency, s11_mag, s11_phase, s21_mag, s21_phase = s2p.parameters(r"Simulated Data\aironly_halfin_lowfrange_realimag.S2P", True)
# Out:
# Simulated Data\garnetonly_widerange_real_imag.S2P
# Simulated Data\garnetonly_lowrage_real_imag.S2P
# Simulated Data\garnetonly_superlowrage_real_imag.S2P
# Simulated Data\GarnetOnlySimulated.S2P
# Simulated Data\aironly_halfin_lowfrange_realimag.S2P
